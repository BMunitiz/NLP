# %% [markdown]
# ### Reweighting a probability distribution to a different temperature

# %%
import numpy as np
import warnings
warnings.filterwarnings("ignore")

# %%
def reweight_distribution(original_distribution, temperature = 0.5):
    distribution = np.log (original_distribution) / temperature
    distribution = np.exp(distribution)
    return distribution/np.sum(distribution)

# %% [markdown]
# ### Character-level LSTM text generation

# %%
import keras

path = keras.utils.get_file('nietzsche.txt', 
                            origin = 'https://s3.amazonaws.com/text-datasets/nietzsche.txt')
text = open(path).read().lower() 
print('Corpus length: ', len(text))
# Out:
# Corpus length:  600893

# %%
# Vectorizing sequences of characters 

maxlen = 60    # extract sequences of 6o characters
step = 3       # sample a new sequence every 3 characters
sentences = [] # holds the extracted sequences
next_chars = [] # holds the targets (the follow-up characters)

for i in range (0,len(text)-maxlen,step): 
    sentences.append(text[i: i + maxlen])
    next_chars.append(text[i + maxlen])

print('Number of sequences: ', len(sentences))

chars = sorted (list(set(text)))  # List of unique characters in the corpus
print('Unique characters:' , len(chars)) 
char_indices = dict((char, chars.index(char)) for char in chars)   # Dictionary that maps unique characters to their index in the list "chars"
print('Vectorization...')

# One hot encodes the characters into binary arrays

x = np.zeros((len(sentences), maxlen, len(chars)),dtype = np.bool)
y = np.zeros((len(sentences), len(chars)),dtype = np.bool)

for i, sentence in enumerate(sentences):
    for t, char in enumerate(sentence):
        x[i,t,char_indices[char]] = 1

    y[i, char_indices[next_chars[i]]] = 1
# Out:
# Number of sequences:  200278
# Unique characters: 57
# Vectorization...

# %%
# Single-layer LSTM model for next-character prediction

from keras import layers

model = keras.models.Sequential()
model.add(layers.LSTM(256, input_shape = (maxlen, len(chars))))
model.add(layers.Dense(len(chars), activation = 'softmax'))

model.summary()
# Out:
# Model: "sequential_6"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ lstm_10 (LSTM)                  │ (None, 256)            │       321,536 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 57)             │        14,649 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 336,185 (1.28 MB)
#  Trainable params: 336,185 (1.28 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
# Model compilation configuration

optimizer = keras.optimizers.RMSprop(learning_rate = 0.01) 
model.compile(loss = 'categorical_crossentropy', optimizer = optimizer)

# %%
# Sampling the next character given the model's prediction

def sample(preds, temperature = 1.0):
    preds = np.asarray(preds).astype('float64')
    preds = np.log(preds) / temperature
    exp_preds = np.exp(preds)
    preds = exp_preds / np.sum(exp_preds)
    probas = np.random.multinomial(1, preds, 1)
    return np.argmax(probas)

# %%
# Text generation loop 

import random
import sys

for epoch in range(1, 60):  # Trains the model for 60 epochs
    print('  Epoch ', epoch)
    model.fit(x,y, batch_size= 128, epochs=1)  # Fits the model for 1 iteration of the datasets
    
    # Selects a text seed at random 
    start_index = random.randint(0, len(text) - maxlen - 1)
    generated_text = text[start_index: start_index + maxlen] 
    print('Generating with seed: "' + generated_text + '"')

    # Tries a range of different sampling temperatures
    for temperature in [0.2, 0.5, 1.0, 1.2]:
        print('----- temparature: ', temperature) 
        sys.stdout.write(generated_text)
        
        for i in range (400):     # Generates 400 characters, starting from the seed text 
            # One-hot encodes the characters generated so far 
            sampled = np.zeros((1, maxlen, len(chars)))
            for t, char in enumerate(generated_text):
                sampled[0, t, char_indices[char]] = 1

            # Samples the next character
            preds = model.predict(sampled, verbose= 0)[0]
            next_index = sample(preds,temperature)
            next_char = chars [next_index] 
            generated_text += next_char
            generated_text = generated_text[1:]
            sys.stdout.write(next_char)
# Out:
#   Epoch  1
# 1565/1565 ━━━━━━━━━━━━━━━━━━━━ 176s 112ms/step - loss: 0.8224
# Generating with seed: "o difference in kind but, at most, in degree. good acts are "
# ----- temparature:  0.2
# o difference in kind but, at most, in degree. good acts are still
# occasionally to many thinking in the same asceted its sensitiveness, and the most
# philosopher who supposed that something is note to the animal and self
# say, and that it is a soul has always so that the strong and
# exposing of the world is the moral past or and self-advantage,
# even into the following of the strength of the same thing the subject may
# consists at the same time the german souls ----- temparature:  0.5
#  the subject may
# consists at the same time the german souls and significations, it
# is not to be sure, but had when they are similar--without peason
# and the good truth and progress of the predictic force to present. the latter of the
# unconditionally of its lolusion and the sight of the ages, and as the
# divine all the subjugation of the world, which all the church as its
# gratification and science, as such as it is something which, were feet
# myself, to see th----- temparature:  1.0
# s such as it is something which, were feet
# myself, to see the taste of which this categrouss of truth and
# obligations, it is insagedewis, the su-bursely in the accluston of reginness
# prejurious miving relations of anwagion to bull same withtbuipous
# must have been the taste in good indes a feeling of the laveloric flooking
# light opinions of the virtues, the drideness of the spirit, and above all,
# immoral escenss and this principal for us. if this first thin----- temparature:  1.2
# mmoral escenss and this principal for us. if this first things its
# things, a in morality gives as thoughtboutifiehly, which act renounce, aking,
# prediccatives, and care and coverclated itself also conceal of
# ourselves. threih thinks--percition of duty by it is to the and society of a
# called mighther, towards lied abustly with there"--period when
# accustomed nows of this morally tongueshabies and done, and that
# never be capable "thinking xmoral senses"--ther  Epoch  2
# 1565/1565 ━━━━━━━━━━━━━━━━━━━━ 166s 106ms/step - loss: 0.8146
# Generating with seed: "s, would be the waste of virtues: so it seems
# to me. every s"
# ----- temparature:  0.2
# s, would be the waste of virtues: so it seems
# to me. every so far as means--indeed, and thereby he is he speaks and
# sensed that the present worldly are of the same time the commander of
# the same time the general position, in the same ways and paradently and
# represented of the same way to around the subjection of the spirit, and
# thereby had to make a rest form. whereas in the most partic men, who
# pshinds has to be and that the same spirit is also the proble----- temparature:  0.5
# shinds has to be and that the same spirit is also the problem in
# histary of imperation. the power of order to see the reason to the
# spirit of the same ways and superficial. the entire of the honour, to
# turn and heavy anyohely, and in which has god that i evidence that
# such a hundred too were should be a delight in the things in our
# whole sharity and profound: the spirits which possession, the
# sense of disgove mankind of that which is promited to the reason----- temparature:  1.0
# e of disgove mankind of that which is promited to the reason to and beyon the
# godlecher has to attain spirit and characters that the sake of the
# world as to every dank even if they wall, the whole is the german
# sought "before mankind" is upon the easy and loss in order to
# be fedifgicule--why not let thin refeally convent anyining, dominism, and how good will
# strong-reality and paraden, which, i be and requires of his pencess, and
# caste: the exception ourin----- temparature:  1.2
#  and requires of his pencess, and
# caste: the exception ourings eftentness harpy and new doorifical superiority of
# mat;--it is still humaned aga one to speak as the last, thus given
# seemp, and no "fatherer--in our eduanyfuls, of colladiem, which,
# but claspeare and finally with taste. manifes formation, only in;
# a that the jews no
# daring to cless or stupety which thereby and overthinling which
# consists theolosing thus is be.
#
# 17_
# poither and perhaps harmon b  Epoch  3
# 1565/1565 ━━━━━━━━━━━━━━━━━━━━ 170s 109ms/step - loss: 0.8119
# Generating with seed: "wish to be misunderstood and
# mistaken? but while i say this,"
# ----- temparature:  0.2
# wish to be misunderstood and
# mistaken? but while i say this, the same all the sublimest to an events that the
# earth of the same assessing the sense of the spirit and the sublimest to an extraordantly,
# when i see of a man who has not ashed itself in the same will as its
# impulsimation in the spirit and conscience of the spirit and
# soul-home as it is a protection and science had been the state
# of self soul, the sublimest of a definity to be some hy, and there----- temparature:  0.5
# f soul, the sublimest of a definity to be some hy, and thereby had
# beed dispositions, as a pride, that is, it is the great polipes of
# a most consight the devised when they have the term of intellectual
# and similar regarding the same in necessary," and is the here, at the
# "hies of history.=--man in the same time a conceivabite of the sure, a
# called them time, that so is, that they are significance by the
# male, i become man are still laugh: i have no dealmot----- temparature:  1.0
# by the
# male, i become man are still laugh: i have no dealmothougally renoves
# for him.--so the kaven, the gerpretians. they call all quility to renot my cause to ad
# afford, ara suicisic blood, ty-mouth, therefore, the badlying
# belief. in germany docngulat, but one for a great mea had where obed, from siety, affinition,
# which only look upon its awakens the instincts of the have of the
# setfilness for giving jesuition. there the germans his lived it, as
# social----- temparature:  1.2
#  giving jesuition. there the germans his lived it, as
# social is liwe.=--effect, it ypeth, than the
# spopt of being educations, the greatest ideawness of such as "everyditime" and healthment--they indifferent tentes
# and pain. thus it loves here "equally" of bwlifbtune--that, he tell
# strength and the sense of name remainingwition, but is aptrourable seed by a
# teages ourselves. and whoever he does not ye may the complexities of another:bly have heinling
# life!   Epoch  4
# 1565/1565 ━━━━━━━━━━━━━━━━━━━━ 174s 111ms/step - loss: 0.8122
# Generating with seed: "e these for truths as
# healing, beneficial and grateful as th"
# ----- temparature:  0.2
# e these for truths as
# healing, beneficial and grateful as the subjectsment of a god, the
# present metaphysical power of the strength and the word of the last
# germans, and also the masters of the strength and profoundly and
# exceptioned, and the man must be the world of the most part of
# the stronger and desire to self-concealm, the strength and desire to the
# present deate of his own imagine, and deceptively of the strength, who
# only to the strength of the sai----- temparature:  0.5
# ptively of the strength, who
# only to the strength of the saint and germans believes with the rest of
# the constraint called good and the world without regards the
# strength is opposed to good to the demanimary of the community, who,
# wished to do it perhaps be it may be lacks ly and regarded as
# christianity in the free spirits of the superiorityren earth.
#
# 158. the fact which the last gradue pleasure of some subject in the barraial
# stupidity of the counter-an----- temparature:  1.0
#  of some subject in the barraial
# stupidity of the counter-and of an anials has been as in order to
# have understand one than untermanss, which have something of the
# earth and respectedm. the yem spirit, maritrous spoins the latter
# of notiony as the soul is personne, and ambitious to life at this is no
# existiwhing from a dempessing unworthy, or under states his own ints
# pain which is regarded as something which generally philosophy, believe it
# the incled cer----- temparature:  1.2
# ething which generally philosophy, believe it
# the incled certain history poysontwrish, we desire could nothing
# of self ofplateful protection and rown they flower sope,risficting
# unrioders--and he who spoted of or-plates himself seriove, una
# degree i think have ewally devox--a-weawon by the conserletty,
# the resulses, to romantice and prosonness may sting finners of
# an rever in the sa occasions for how comes our eolo place sloving and
# fougher, swell.
#
#
# 1:5.   Epoch  5
# 1565/1565 ━━━━━━━━━━━━━━━━━━━━ 177s 113ms/step - loss: 0.8040
# Generating with seed: "is unhealthy
# excess of feeling, upon the accompanying corrup"
# ----- temparature:  0.2
# is unhealthy
# excess of feeling, upon the accompanying corruption, or a sort of act the
# strunger of the same successfund self-contempt of the struggle and the most
# manifests of the spirit would be even the love of a man is a
# chealition of the same and the wort of love have itself from the
# standfrority of the earth--i how later rele to the excess of
# reason--the exception of the future of the struggle and the relations, which he does
# still an unjust the same ----- temparature:  0.5
# e and the relations, which he does
# still an unjust the same words and delight in the same ascete-different in the
# english means.=--the shall for it is the result of my virtue and
# sensually enough. the exchange of a mediocre as an act as the
# imperative of his heart, which regarded to mere simple, as in
# europe, and makes in the end of europe the former are, the instincts and
# contemporable enjoyment the conscience of the religious and more and daring to the m----- temparature:  1.0
# the conscience of the religious and more and daring to the meterance
# of arogupes. god in a last nature was to be and different!--willy,
# which the inventional conscience of general have to an irriminat
# excessing violant men are sinuled believed by the generatent
# people hard the german sin and self supremagic. its who increase corri-iver: we chealeous
# soren and the old other surms and obvious as an artistic discever from this
# knows of human liver without lab----- temparature:  1.2
# artistic discever from this
# knows of human liver without labny makes us regarded his own dealing thing
# intolucnable destrric pressumed: furmless ever speak. how nginly as if no
# most ageabity before my thing dills actaptable of the gundom
# proritral vations, it betray taken interior in the "traight that styhes of sick and lack of sungered, more far about
# europe, from our origin. but i vain our other know. he lasie
# been a semble so, that are god when some onl  Epoch  6
# 1565/1565 ━━━━━━━━━━━━━━━━━━━━ 167s 106ms/step - loss: 0.8022
# Generating with seed: " limited horizons, for
# immediate duties--it teaches the narr"
# ----- temparature:  0.2
#  limited horizons, for
# immediate duties--it teaches the narrowily cases a person who sees the same
# time and at once sees the sense of the world as the tradition,
# which has been fully not only to the subject the contemporary man and the latter
# present matter of the world as the tradition, which a man who has a
# powerful and deceived himself that the belief in which the spirit which
# the greatest expectable sense in the same with the sense of the presence of
# t----- temparature:  0.5
# ctable sense in the same with the sense of the presence of
# the belieoder illow them as a man who has a sort of destruction of the ears, and where al
# belieting methras an idea the basis of enlightent and incard. this is the
# secondary free spirit under the way and artistic and consequences which
# person that is to be a soul and advantage that the blace of the discovered with
# themselves with the testate of the spirit and deceived himself
# of will profoundly and----- temparature:  1.0
# te of the spirit and deceived himself
# of will profoundly and with security who the threath and one must
# hast futlessionableness and entered its arround and of old outspearably and thereby here it is the
# helpine and dary aristocracy for general in the entire moral," more afford
# at this causes as forcesring and grew: wear, who concorredant
# phenomenal, that way fllwgin mistanked that in good and strong-injudg has only toleby in all things";
# and why kspire whi----- temparature:  1.2
# ng-injudg has only toleby in all things";
# and why kspire which benearvis down that there by phinels our
# toulad -through beasiluams of all that poison one's even to inflo toicn
# and ethick. one may ready believed, has compressed and name--but
# refulter. at the teiats to be" subjectiat, nomable for the greate moyselves,
# impospition, therefries this, on an arrocusince, of rank and of that
# accept bronger, the soul loven into which oncasious may make usefoed-easi  Epoch  7
# 1565/1565 ━━━━━━━━━━━━━━━━━━━━ 176s 112ms/step - loss: 0.7986
# Generating with seed: "such
# matters, and without the craftiness of the plebeian, wi"
# ----- temparature:  0.2
# such
# matters, and without the craftiness of the plebeian, with the structure of the world, and then we makes one of
# the same will to place of the problem of course, when one must be
# garbable to place should be of the more the world securess. and who conscience has
# that it is a sources of the superstitious and discovered themselves
# suspicious to the problem of the promises, and makes them senses the
# present man which he sees the sentent when they would be o----- temparature:  0.5
# e
# present man which he sees the sentent when they would be of the advantage of the
# higher souls and age and that science, has not sutching the same thing
# that will prefers and some much longlic thereby here, the condition which,
# and also a hund some truth of power, so that the struckness of "modern
# ideas" pasional power--he who has afforded the sentence of the moral past for a
# things are the most different conderence of a disception, the
# music of the same ----- temparature:  1.0
# different conderence of a disception, the
# music of the same knows?
#
#
# 7
#
# :fell pitterious and determinate means.=--for that it is not only the
# depresiness of favousity, if i mean to saffer "be daring trof.
#
#
# 13
#
# =the how to be disclared, csuntess for an opinion is everyd.
#
# =jegally one may time--for example, the philosopher,'--beeas, at once and
# laws of the sacrifice with the ayocused in france as the motives of
# the power, as falsehood of the determinate my----- temparature:  1.2
# the motives of
# the power, as falsehood of the determinate my wick of error[wrapse, almost
# theminity; i have neath too were one has not ser"sym--heiccorded, condemabay,
# with a re ay immost our order and recognismof.
#
#
# 13
#
# =e
# self-coffort," with free which docto, even his flitent and decaaded paities;
# which e say sudder-calcumation of the many under successful perlision,
# of willing--it is at once sympathuu:--loving, to the general force
# of any the gramble in  Epoch  8
# 1565/1565 ━━━━━━━━━━━━━━━━━━━━ 174s 111ms/step - loss: 0.7942
# Generating with seed: "g
# how far they may have here acted as inspiring genii (or as"
# ----- temparature:  0.2
# g
# how far they may have here acted as inspiring genii (or as the
# contrary of the same time time time the traditional of the antidion,
# and the more of the prooncasmed, as a prior, the subject man
# are, as is taken to him to strang the same time timitation of
# the morality of morality and prisences: we stood the imment is
# not only too thinked when the word of the spirit which has been
# first, from the most difficulty of the spirit and the rights of the morality----- temparature:  0.5
# most difficulty of the spirit and the rights of the morality of the same time
# ourselves, is not to be and will be too literate upon here, and
# the fact that the things flaud which all the person could likes we heart
# something with regard to that me tradition. a subjugation to the
# charm of the same time timiadable in which one is resting, and
# can be promised upon, and also more for a woman, and was a doubt that he thoughts
# they are one is almost every ratefu----- temparature:  1.0
# a doubt that he thoughts
# they are one is almost every rateful, and praises.k--howe, final,
# always pains, irrirst, fully disinstitude, contrary to the prordment of nesplace.
#
#
# 271. a varioned concelsned ourselves the fred think of the beauted,
#     an     give mes aften liegwilike, has longed to call a man
# is consequently viewable claste--in since our very organic. but
# what you can in litage wish to contain to
# europe very since from matters). -he would be th----- temparature:  1.2
#  contain to
# europe very since from matters). -he would be the poviten men: thor here est decises him to
# danger
# to talth a woman: them sympathy anything tragguas love--i have to
# say: "i honge and invurers hardies upon their miracle--as ferves
# day: recapters law ith suicordes itself in our eye of the varietled
# ipine. absely according to which you waity
# from the spirit of a dispart.--and we must above all the sket every
# has ,rapy, icedvenceal right. with cate  Epoch  9
# 1565/1565 ━━━━━━━━━━━━━━━━━━━━ 177s 113ms/step - loss: 0.7944
# Generating with seed: "ow to the
# end what is "fixed" about them in himself. occasio"
# ----- temparature:  0.2
# ow to the
# end what is "fixed" about them in himself. occasional causa is instigated a consequence of the
# pain, which has hereto comprehend to the same time has been a social chical mediocre.
#
# 13[. owing to the sure of the spirit and art for every new, therefore, which
# case so entermans the strength of the spirit and sensus, more
# consciousness of the man who has thorg, in the last convertion of the
# present maxing to be a moralisting destruction of the same ----- temparature:  0.5
#
# present maxing to be a moralisting destruction of the same emotions, as
# christianity and something that is a more profound to stand among themselves
# and this facts and statele, i believe in the same religious habiture
# and betrayed their own nature,
# and more fellows of the stone of the most power, which have his
# engain--what such pressure for vololours, and nothing must in
# the end that it is present to any call a philosophy of the sure, will to be all in
# o----- temparature:  1.0
# nt to any call a philosophy of the sure, will to be all in
# oicestation. and all last duplelly systeps accessually that one of our
# france, and waking up in the "thought" something in their spaced, perhaps as
# falsento it would never have no longer gook to the life of virors, neednes, this nations
# for centuries why inded the will to for the thingh of its longingle "nable":
# i spoken. there wish all the pates actand all loonced that he hou
# there doctwand, of an----- temparature:  1.2
# e pates actand all loonced that he hou
# there doctwand, of anyothes at once, wfem intercourse--according to laveble
# fall intying, bood the what one immutands thereble well know what
# is, dreadfine, people undid those under temonen times he understand
# with longer cotre, he called by be a hundrylokely to the knows as annicers of the
# estage of his satisfal againo: is regarded as he does the childish of
# the convaceriag of this exist
# rupility in the soul.--every   Epoch  10
# 1565/1565 ━━━━━━━━━━━━━━━━━━━━ 176s 112ms/step - loss: 0.7920
# Generating with seed: "hat seems dangerous to the maintenance of the community, the"
# ----- temparature:  0.2
# hat seems dangerous to the maintenance of the community, the
# present selence and desire to the strength of all the strengtheng of the same
# man, with a child has a sore all the principal and standard's eye say of the same
# marins, and is innocence been the strength of the same time of the
# super-tompority of hereto has been to the world with respect to
# the same thing that which is good tearlities qual far the same
# men that the worst of his spirit and soul, as----- temparature:  0.5
# l far the same
# men that the worst of his spirit and soul, as the contrast development of man
# is present for the absolute mysteries of a metaphysical sense; we have
# also action, is it now, far the made interrogation, in the laws find
# purpose. the charm find that the contemporary respects to his self-severed by the
# presenter: or justice, as it is something for its own interestion,
# and the will to the fact that we has great experience also in
# a man who has de----- temparature:  1.0
# e fact that we has great experience also in
# a man who has dedised our experivence continuence attention.
# they called superressed upon what he would confinion have been
# for the spiritual and evil, and goving escerness about our prior
# topart of himself.--first a sin, as well as a native, he makes him attain about
# imply changed by frrentries from us: "the matter of prea
# concerning commander and among soned, nometh-perception for which i resemblihe
# men as the ----- temparature:  1.2
#  soned, nometh-perception for which i resemblihe
# men as the barbarn imbine most done, mave from worth and mbed, as are
# obling in paratobarish, rude, was thoughoger designated philosophers had grow
# mazes the things of the general philosopher aways path jlys lives are
# not yougkoun, make a masters of outs, appatence, critics. with his most
# diing securitary land elevaters than the unstill other stranges, provobutely,
# expluiness, eithere and skcarage rewarding   Epoch  11
# 1565/1565 ━━━━━━━━━━━━━━━━━━━━ 175s 112ms/step - loss: 0.7860
# Generating with seed: "e english utilitarians: how ponderously and respectably they"
# ----- temparature:  0.2
# e english utilitarians: how ponderously and respectably they will be the will to power. and in my viviss. and it is
# and for the fact that is not the will and the "things of the lastt," the reason of the spirit and
# soul, however, that is to say, and the good man is active and all the spirituality,
# has at least the problem of the same thing that for instance us attached the same succertainty and subtle truth and
# soul, it was the same thing that the latter go----- temparature:  0.5
# tle truth and
# soul, it was the same thing that the latter good taste; and if, could says the same succertainty and the community is not to be and
# imongators of stupidity to come texistic man of the same things it was the
# instinct of language is easily with the same thing that the distingulance of the last the worke of an
# about this and principal state of life of the most values--it
# incered to understand that in the community is it is really at once
# frequen----- temparature:  1.0
# rstand that in the community is it is really at once
# frequently soncalled and under whihement of the lone-circurity: because self-subority and
# subtsurbouts which we neighity philosophers are time is a pud among the whole refinement of a wandart
# has been men hill to dependent reput one will accept all the are of the first
# mentatic in should previally progress to one's spring has concerning
# it. for whom the man should always surfile, and such an eternally
# in----- temparature:  1.2
# whom the man should always surfile, and such an eternally
# individuality which lookslograged and clearrily; he would be backed of a
# ralively inclination and sensition, or good invalid an europect.
#
#
# 65
#
# =characte of justice. for there for no books up nowing: the man of
# "transceshion": "swickove and artiful" in the ewhicus of soness says-instinction, howegy, as immoral
# quical tendersearly, that by whom other experiences which hencefly bongrous of "nation" su  Epoch  12
# 1565/1565 ━━━━━━━━━━━━━━━━━━━━ 171s 109ms/step - loss: 0.7815
# Generating with seed: "eses? why does the first plausible
# hypothesis of the cause o"
# ----- temparature:  0.2
# eses? why does the first plausible
# hypothesis of the cause of the spirituality," "world," which
# a degree of saint and religious from this very dangerous into
# european like the masse of the saint, with a nations for conscience
# and soul, the man is believe in the most spiritual sympathy and the development of a moral
# specializing of the present day, as a world new distinguism and
# soulad and soulg, and in the fact that we concerned that is to
# speak the brue h----- temparature:  0.5
# nd in the fact that we concerned that is to
# speak the brue his talent "eviden"es. and not to be capable.
#
#
# 130?. that is precisely from fitters of malicism its like the relations
# of mankind, as is mutifical consequences, from the most difference
# of here, and is even the will to all the rearm of the last, as
# regarfaps and even his effect ethic, or also the best enlihisely
# sacrifice in fact the "things" and "non-possitive" and instinct for
# the words of relig----- temparature:  1.0
# ngs" and "non-possitive" and instinct for
# the words of religious. not rule upon the times--socised to us.
#
# 171. the plato should be honoured--and even him that demateforated
# by enthang, and finally advancemed delightzusuals: "the latter
# power is fascinated in the most discoveres of truth.. the promises in
# the first of enligher help, ud it is vury to one wishes to have
# our eyes as devil a man who deceives himself, he may be arbitrarled with desire,
# they bon----- temparature:  1.2
# eceives himself, he may be arbitrarled with desire,
# they bond to his acl of the sympathing morally belief in the ways upon
# what woman is manifested, equally thought!--this system of a
# misunderstand this mather a mankits kind with the bounding bepocunces of ""man"1
#
# ;
#                      ?"         hose himself they are inflicted
# believes begrot, the most accoun net has co
# very deation, for which as we now every read further his aevents himself which.
#
# [2  Epoch  13
# 1565/1565 ━━━━━━━━━━━━━━━━━━━━ 172s 110ms/step - loss: 0.7749
# Generating with seed: "y civilizations. we contemporary men feel
# exactly the opposi"
# ----- temparature:  0.2
# y civilizations. we contemporary men feel
# exactly the opposite of a condition of the strength of the strengthed in the same
# sense of vanity, who conscience is desired in the same world, as
# resten and friends; and whose different regarding the sense of creatively and
# most cases, a manners, and whoever has at last the same time
# one from the state of himself. who is now the great who can understand
# what we can be devouval as a sense of conscience of the stren----- temparature:  0.5
# hat we can be devouval as a sense of conscience of the strength. they regarded as to be and soly
# called upon their existence and self-seturistive self seems to ment the stook who let
# phychockopes of his sure, slaverly stand still regarded in many distord and
# reasoning itself is probably as is evil at the jewher of the
# old a securcs of life and its truit, for the profound viction
# of life and its like revoluz(, and consequently of the estimate of an extent, ----- temparature:  1.0
# ke revoluz(, and consequently of the estimate of an extent, as
# well as the imagine of "formation)." he passion funds of germany
# which has hicle refuged lime one, reemes, whose dispensiousl
# arose when they were denounted as good too irrifging experimentally
# smill noble they inner
# themselves with themselves himself in their froneus, and can certain
# sacrifice of all abif-caticism, as though--as looks upon as through
# anyonhe, which has been the right train int----- temparature:  1.2
#  upon as through
# anyonhe, which has been the right train intention is better,
# bruughe of the p, the cloud that can uniditure: looky, invaluance,
# a berng thought suffers the teme and a sori(or exerciseful, and
# hardoricus incisement of conduct as well, they not say betrayed bad is he f. i beliem takes whichful contaction does not
# nowadays before one to cleavite rest, i, and likewical happies and
# meck, to counter all the german most dangerous, and even after
#   Epoch  14
# 1565/1565 ━━━━━━━━━━━━━━━━━━━━ 175s 112ms/step - loss: 0.7766
# Generating with seed: "-we are equal!"
# at present, on the contrary, when throughout"
# ----- temparature:  0.2
# -we are equal!"
# at present, on the contrary, when throughout its cause is a sort of readily and
# social instincts, is atavous to be as its likewical sense is in
# feeling and sense, and hardoracually belong to the sense of sensible for ever
# would be even beto the demand is at last to be and bad inter ater
# anyothe, which has he would be let the brute his own distoures and
# self-renounces of the free spirit and displays to the strength of the same and the
# whole ----- temparature:  0.5
# irit and displays to the strength of the same and the
# whole distories of a good distinguish has comprehended religious
# power of sociently belong to the same asses itself is desired. the seem of the spirit and
# subtle-plantive contradiction and feels itself, the conduct and
# the imperative personal valuations of entire and capacity in itself
# all the strength and concernation in which the esterming of his
# significance of all disinterent itself from a thinking ----- temparature:  1.0
#  his
# significance of all disinterent itself from a thinking hording
# to mankind was the same and is that a preval presse force deec. he is we have puose
# itself to be that, in this earse into choorc deriotical cuntintly
# enformer and hardouremental unlegions and that remaining, more
# selflency, more devalority of learn to one's ested, very dewiling,
# estimate deceives, we first enligher degree for time believed itself
# in a barble judge. west dose floluhed by li----- temparature:  1.2
#  believed itself
# in a barble judge. west dose floluhed by liminary cirishes some.
#
#
# 1
#
#
# the bror diffience''untay from a virture, undeventness, methords, the brangument, perhaps
# also. when we now take many dryward the hero once donsersedness which py, and
# all the ccionstrar and eyes of such as you around, erringes.
#
#
# 127
#
# =eterisome the nature of the same duct, "         the  same emotion
# societyritude, and do, the instrain that the determinate for his pas  Epoch  15
# 1565/1565 ━━━━━━━━━━━━━━━━━━━━ 175s 112ms/step - loss: 0.7758
# Generating with seed: "nguage of rousseau, schiller, shelley, and byron sound to ou"
# ----- temparature:  0.2
# nguage of rousseau, schiller, shelley, and byron sound to our very
# significance of divinian and standerty and the most innocence of the world with a cleave of its lolic more
# far about themselves with the sure of the freedom. we are not
# deselt the problem of the freedom as a sistance of the french as a
# place of the same time the case of the present divesto make a man which is the most
# individual men, as it is not one of the most innocature of the world.
# so ----- temparature:  0.5
# n, as it is not one of the most innocature of the world.
# so the wice as if they would repute to experience which are also be indeed
# to the exhaust of its lovelble, or dealiang farmed his prightd,
# and with the rating of a means alike us what is taken of life and the
# most darty; and it is to which the brought of surprise, and in the
# common and the distinguish for other power and with the disception of the subject etgers,
# are talvation. the but a ditterious a----- temparature:  1.0
# of the subject etgers,
# are talvation. the but a ditterious anxuxmation are in fram
# minds advertopetyr's s"poses of view
# inner its own injurems advantage: we are combemfulness are to
# every demand, by why sise the usual remain faith in a higher, simily,
# even skepled to this mat;-i bess of, and in the commenling successful of religious
# christian darter--owes imment the disposite of a deeperieties, his eyes,
# philosophmisical) are certainty will find, in any, h----- temparature:  1.2
# s eyes,
# philosophmisical) are certainty will find, in any, he were, very
# callative, all the follows of natuons, which we seak as god.
#
# )jteffect moreoving chuldeness to bring be retrotededness of ain it like
# vassed--afd make themselves upubatement let physion to its true
# vbutmmonsy darasnes, if yeastime higher meaning, or all culture,
# merely tad appearance. abselaflemng perceived through all she is telang and doubtful
# to self-re in requirements, with it wi  Epoch  16
# 1565/1565 ━━━━━━━━━━━━━━━━━━━━ 175s 112ms/step - loss: 0.7726
# Generating with seed: "ack to darkness and untruth: for fear
# of the consequences.
#
# "
# ----- temparature:  0.2
# ack to darkness and untruth: for fear
# of the consequences.
#
#
# 29
#
# =so thar  what ower to the survalism which only a subtsus. there
# is always in the same time has been the actually princificity of the
# spirit would not have athreatoun an intermination of the spirit of
# moral culture and states and finders and reprisentations of the
# most passions states with the states adorates and cultured themselves.
# inthics, and there are states which the senses to the most ----- temparature:  0.5
#
# inthics, and there are states which the senses to the most me
# impations, indeed, the instinct of all the conscience of the
# spirit would perhaps the history of the strength or nature is the
# deals to present happy at present himself and with that it is
# a god. "moral indiration.=--as the expression of the superior
# to the strength and most case of the subject the redispated ages of the strength and
# consciences-her in his eyes are more fastidious and metaphysi----- temparature:  1.0
# onsciences-her in his eyes are more fastidious and metaphysical
# peoples, and there, all sorigt as it is a loak beasing elevated
# that something that lacking the attempts to the human dangerous
# intoldity and nonarity, which are ensuse of the hypothesis in
# own suspicion. there
# refined, and wheref, he setted the port, an acchue shelec, natural comprew
# freedom for god-lies his case, this into his pure of their deals as
# restegning in man--that this secuble into ----- temparature:  1.2
# of their deals as
# restegning in man--that this secuble into its and are to be strong among
# peoples, or means, often they are only amord of their fear and there is
# there is a born adventiry with order to its imperss: all nook,"
# and "merelves" by what paid only but absolutely and mgetal vice,
# as a greelrs of sympathy in europerhan naturalfer usument under
# an many experiences of solistiveness. but only is decapadited
# to ge have to teach, the lawing with dut,   Epoch  17
# 1565/1565 ━━━━━━━━━━━━━━━━━━━━ 176s 112ms/step - loss: 0.7663
# Generating with seed: "ed longing and whatever objects he may encounter must
# suffer"
# ----- temparature:  0.2
# ed longing and whatever objects he may encounter must
# suffering in the same time to the stority of the most part and
# self-responsing the morality of the order of survivally enjoyment of such and society. there is so
# much therefore, the stranges and the discipline and for the same
# mind is some man, therefore, the selectian and decided will and for the second men, to the
# same time to the most surprise faculty of thinking, the most man russions and
# sense in t----- temparature:  0.5
# se faculty of thinking, the most man russions and
# sense in the freedom of great subtle, under their own system of
# morality is desires, in self-great, perhaps, that he gets his father than the
# card of the thing in their stronger kantam all their intentional and selfish
# man with the discipline and falsification, the condition which is no
# observation himself which constantly belief in the more fundamental possession,
# in him in the old a standlater of possessi----- temparature:  1.0
# ental possession,
# in him in the old a standlater of possession, or an immense more
# free inexicted by the development of old mistaken, and there
# commands for the sort of matters of fellowing culture, all the
# pigation, an our entirely! this is a standle of feeling bring who will
# overstered from a circles of trum: for therevarty and fagiliest, it as
# sigmicists its bargained be evil, and likewise extent being who
# in which there is no near it as delightvessands----- temparature:  1.2
# nt being who
# in which there is no near it as delightvessands of their nircold
# with styr tod--and linesifliciwing and stated, psychology, and to
# overme thinks even in "immedity," "so the strangely pivility,"
# healthing;d--as let us lain their portaopible that which one is it.
#
# [2] charistic can be work, s for this dongvingty, is unrivest: this
# satis to clought in the fact that under disgivates affirmow and they only attenation
# to them to kpine hidd; leadsiby  Epoch  18
# 1565/1565 ━━━━━━━━━━━━━━━━━━━━ 174s 111ms/step - loss: 0.7636
# Generating with seed: "s a
# misunderstanding about its tempo, for instance, the sent"
# ----- temparature:  0.2
# s a
# misunderstanding about its tempo, for instance, the sentiments of the spirit
# has been compelsed by the races of the superiority of many of the
# spirit would not have been the same with the sense of the most emotions,
# as the most supposed sound. they had to be the wear, and that
# it is a superior whom the most spirit is comprehender: the interrace of the
# soul to the anti-semitarity of the world as the immoral sense).
# man all the present divining of the sp----- temparature:  0.5
# s the immoral sense).
# man all the present divining of the spirit would even make the art of the
# superiority of christianity is problem and sure, the truth of all soul
# the man of the world as the dangerousness of worldly, which we makes which
# the immediate man who conscience had been an other even under the
# successful of all the supposes of the law-givish and self-evils, or
# so that what precisely by the sense of the world, as well as of
# thought it is at res----- temparature:  1.0
# y the sense of the world, as well as of
# thought it is at resslugulate man and consequently one of the origin of
# exposing more faius, thus, we would seems to os--namely, perhaps, that we have always
# established of its tore equally and in such a triumph of supiously,
# such an opinions of strength origin. nutons among to an equal untillemonity. it
# is he really that even in the same way truefloly of the chinaclly
# discition and circumstances, with the free words----- temparature:  1.2
# e chinaclly
# discition and circumstances, with the free words. and what can be
# belien in elefurenca, and old selfic).--what does it case the
# old self-inspire the mother past mush, what is only like themselves to anb
# berring and been a cleave of rad; power. how much ood on the
# other who say propitting these finalive of philosophy them at an
# explaration asceticism of animatence, without civililes class, still lightsging. there
# is shapish of the centu: but in   Epoch  19
# 1565/1565 ━━━━━━━━━━━━━━━━━━━━ 180s 115ms/step - loss: 0.7614
# Generating with seed: "true, and beautiful,
# and let all kinds of motley, coarse, an"
# ----- temparature:  0.2
# true, and beautiful,
# and let all kinds of motley, coarse, and thereby had goo only
# stranglable in presence of his spirit and science, and thereby had to
# render of the fact that it is all the same alsocestory. the existence of the
# deal with the exceptional man who has a society of the actions of the
# presence of the same also, the sense of the world as the truth of its loling,
# and now the same time his superiority of high self-considestable, and thereby
# for ----- temparature:  0.5
# his superiority of high self-considestable, and thereby
# for this sentiments of the personal value; the aristocratic same
# essedful in all thinking is necessity."--but about much all the reason of the
# word friends! the condition of the scientific in little teding to an
# aternation and science, and thereby as the imagination of the
# cost-supessibility of charmity, the eye belowely the development of his significance in
# divine and confound. in fact, the world as----- temparature:  1.0
# s significance in
# divine and confound. in fact, the world as something which, threateriuse, and more
# inclosed oner to e, befect to think the best orgener, the european
# reasons which encou!ly-today different to take ablitb), whom as
# retires merely perhaps also well; too bad?nonas of typiral strike
# _noon, too ldranness--this nankinonist neither in a prevail and
# mind and the mutuoly case, a has above of the whole or communical to
# any of the idea to the earth.----- temparature:  1.2
#  of the whole or communical to
# any of the idea to the earth. (as looking man and conscience
# into the doings false of hhinking--the terms are all the certain
# this, if yet nothing back pohing that could plide his !" said and
# lives. another telrward. myself anyphild perhaps as calculable for
# inso art sympulnwardish of wonth and woman: asd, to have to say,
# to the sort of eccousal suic--and risely and sorrow, for instance, in
# precisely brifd in germans, and par  Epoch  20
# 1565/1565 ━━━━━━━━━━━━━━━━━━━━ 173s 111ms/step - loss: 0.7567
# Generating with seed: "similar means. the principal means of
# effecting incantations"
# ----- temparature:  0.2
# similar means. the principal means of
# effecting incantations, with the senses of the senses, as a sort of destrain, the
# conscience of the world is the most sustation of the senses, as
# choorse, and with the common society is the result of discouson
# and something that is the basis of the contempt and desire to the things and
# conscience of the spirit and self-reculted and subtlety of the
# conscience of the spirit and self-receives, and in the sense of metaphys----- temparature:  0.5
# f the spirit and self-receives, and in the sense of metaphysical
# sport, the survaion and effecting spirits of temposing from the genius and
# conslecuration of the desire to his task, and refined consideration of the
# possibility to have been understand it.
#
# 296. with it is extravences of a defining schopenhaues of the world with it: they were the
# majority of the past mentants, and here all the corresponding comprehending
# and devil,cent of the world with one ----- temparature:  1.0
# sponding comprehending
# and devil,cent of the world with one make on bad taste of and
# done, a distinguish and the discoverection of the world as , an
# amive sented likewe--like moot only mankind will go know leadon and more
# forceps and lighted force of some surficbeg, by means of the german spirit and the
# odder the necessity. for the refurion are the degree of remororish,
# ascriatences they are vissing--he must acquire the ofgeners of his self
# recept with it:----- temparature:  1.2
# ng--he must acquire the ofgeners of his self
# recept with it: they state a moment and full faircowage slave, sutcoround, as
# reputedness how verill fall from bad child on scateg, lit so
# ventured sympathy formed and maid: looks, that valuate the eye,
# this is among the romans, who generally slaves long and potew
# manifelting horrs about all the longings of a during, and obvicence and
# frighth, unticidated, from germans and asceticians he long under that, self-ro  Epoch  21
# 1565/1565 ━━━━━━━━━━━━━━━━━━━━ 170s 109ms/step - loss: 0.7519
# Generating with seed: " than is generally believed.
#
# 292. a philosopher: that is a "
# ----- temparature:  0.2
#  than is generally believed.
#
# 292. a philosopher: that is a proper fund to find and decided
# when i cannot be does not perhaps the most powerful of the same
# manners, manifestating itself in the fact that it is also a moral
# spirit and body as the basis of the counterpands of the same
# man, who can be former not be under their conscience.--so that the
# entire conditions of the contemporary motives of the spirit, for
# instance, the contrast kantament of the same ----- temparature:  0.5
# he spirit, for
# instance, the contrast kantament of the same nights, for example,
# mankind make use of all in the command--and now the whole man
# are the greek and difficult to make the god. let us can be captived
# and likewise, as and god-lose natural and distinction; in the
# englishing in order to arreastion the contemporary modding to its
# still. once mist one finds and desired to the many of the masters, by
# protection of the same who sufferings of the world ----- temparature:  1.0
# ters, by
# protection of the same who sufferings of the world be claves
# for their nimble, which he dishope upon by and operation to the community to him
# one must tapk, "relly and instruct, each cride--if allow in
# myself which was possible to be "i whole neither things in a
# pnespection in the delusions) of natural
# possibility," indeed, not on the brute, the truth is shaek as to what i  be danger
# of its own insqual personal advising its strength, and proud,
#   ----- temparature:  1.2
# ts own insqual personal advising its strength, and proud,
#      at the simple, his fine life and but by the opposite entire
# hand which iscond to be rutualled by regarded in my self-bongherate regard to pa
# must that more back ear, not not one knows the malage, it is its
# strength and the imperlable opreess of exercroment--namely, one my
# can low me have no wrongly, testesy the leach one in heal, indeed, he
# goals, at first the breaking to
# listlour. the more cha  Epoch  22
# 1565/1565 ━━━━━━━━━━━━━━━━━━━━ 172s 110ms/step - loss: 0.7492
# Generating with seed: "truggle and wavering! to be sure, an ominous new superstitio"
# ----- temparature:  0.2
# truggle and wavering! to be sure, an ominous new superstition,
# has been rendered and daring, and even him to the sure, natural
# pain and the discipline for the same wild to be so far as it
# hitherto been true. it is even to the exhaustion of the superficial
# scene (to have its strained the characterist of the superstition,
# emotions.--it is not the pitting of the strength is and laugh and
# refinement of the last religious power of superative for the
# spirit of t----- temparature:  0.5
# f the last religious power of superative for the
# spirit of the a man longling in a necessary and roden and with the democratic formation
# of life? that the interpretation are there is a sort of readness, it
# has reconsideding badlyanded by the relationship of the predections
# nations of the ethical sense, they will be everything solitude!
# until even in the same many interrace and delivere the interrogance
# of herm, or eventure to the point of others and partly----- temparature:  1.0
# gance
# of herm, or eventure to the point of others and partly remoresorden
# music, they does not misunderstand be ever die said against all
# touches that the idea of delivere rewardised upon, slagemes of
# enilo:--only in their "worth" and as a kind of how can be arroped.
#
# 143. we all know
# a conscience of the worldkent--as a distingungaring, insignize, and only
# be remaized in the inferitian alorm, in many wuxleble abstrutube to the neceforous emotic. the
# belief----- temparature:  1.2
# any wuxleble abstrutube to the neceforous emotic. the
# belief in which the endrar--what willings, child with all the
# many e i, one raken but that the pre. enlosieating, hypsim,wandf-in partic faitn: those
# honour, vanit-beduceratable of-sain-deriminating-mind, or had practical mandincing, for
# disclange--namely, i a labod men accomplato elelyts earourers one places when
# was give others humated, let us rate of one another and demand, proceativion, be
# glow inte  Epoch  23
# 1565/1565 ━━━━━━━━━━━━━━━━━━━━ 172s 110ms/step - loss: 0.7496
# Generating with seed: "his soul states being falsely
# viewed and his personality bei"
# ----- temparature:  0.2
# his soul states being falsely
# viewed and his personality being a delight!
#                                                                                                                                                                                                                                                                                                                                                                                                   ----- temparature:  0.5
#                                                                                                                                                                                                                                                                                                       s the weat in us
# sughom. and the most particiolo-if these power of the man which
# originated a spirit (regarded as that it is a soul which as the
# whole of the heart, i----- temparature:  1.0
# rded as that it is a soul which as the
# whole of the heart, i manner a races are means of worth, invent responsibility, is there
# attait, that a bad are enduality is inspired from which one paraend has nothing unterwands with
# which the centimateful, but the entire him. for instance, but because of
# the ascener have really at once not one's liment
# ourselves. the term umpicious than one understanding just "aloovt "frush"us.?
#
#
# 1k6ily have boon because so after ----- temparature:  1.2
# ust "aloovt "frush"us.?
#
#
# 1k6ily have boon because so after equally as it is determined
# prefers and for the moral cowerly, the german spirit not acts what
# affuible compleptive seriousness are enchate! the common it beas;
# ...
#   h hitonest aoled t  thhhhoeh t n ise  o n  os te lus s ohe lr eo amirce hac srgem thhee-ea n  hifitn r ininae ot o onocemvh c reidi fs
# peprist lao arto sam theg thre ses,  miaseptn mrctor
# i oolls,
# a o.-cfr
#
# esrosn lnce san altrlpseome f ta  tha ue
# or tohhr  ,cmuusf nre nf  hesgieye sceakttingesesesg.i  mitho acel, lact
# ieitsulbwone oho_nhs  heoce  wardhan hrelatrm o alg aintcciren ss ehdweeaan edhhemclnet, toutae
# th
# yee, ple-it bl sdoadnse min3d s -tda ----- temparature:  1.2
# edhhemclnet, toutae
# th
# yee, ple-it bl sdoadnse min3d s -tda nsefrsnahi hslop ,pto cheemyc eo uy eps
# aed ysn y
# t beleo  os bu nff:,te wheeni  tsxiid,ohys rpetino,guitumct rot th it veof erlfscri rasaiaasimssroe ae n nhhivivrrisoiolleysi,mem ite ivgl,mrrym,e-lo di-t
# tase  sh w s n diced,t rtrse usisrenginheelycs orvbeithitititost0cste u iu mederouol
# d th if,ynac
# rmdhnlaaertmof chs, v a,, fhenlmligeauk wian
# "ctawoi thu al pocg daglsgunv lhntnjocs co lakllu
# do  Epoch  53
# 1565/1565 ━━━━━━━━━━━━━━━━━━━━ 173s 111ms/step - loss: 3.2957
# Generating with seed: "and most successful disguise which the german is up to
# nowad"
# ----- temparature:  0.2
# and most successful disguise which the german is up to
# nowad  ti  ann  ha  orn an ta ifis  f ao t a that exit an aosb ife ner ane ate  as  we tat   fere th eein ande te are t ean ta ath  n the  an  ane  ntee and ther tertinee tl atit an in f me t th to th whh in in an aiseor  in tit  f ti th  angd ihe re theh foe atee  fen at te hee i ne thine then tn th theas a  w enne ene th t2 te afs on a n ho t t aat tao ph an eo aw th  hf r  th and o of ne ehe fhin an----- temparature:  0.5
# t t aat tao ph an eo aw th  hf r  th and o of ne ehe fhin and hefeon ste he so co  in as  dgieedemratho whe thrdio moe thert w totecas s init the thet tn theeff on  oatilit qr he n man je a s tert et oel, in ha timex ain  hera  ee fe at: th  ee it e  fof ofu sithh t wheriitto ande anoe theqn nte anee fl oaleee th othf on im
# d t  s iait ne th  me an it i eneuthiang y aorwa  hepe t ihl al ulini eitls t ian isrp t thuetieftlir the th mo altee in thoe l cheis----- temparature:  1.0
# ls t ian isrp t thuetieftlir the th mo altee in thoe l cheis    fhosucsgareeana =ikd
#
# ss dsbaw an -nfnoeb def reoispi  sittir inrslyeb r ext icn seyre, ph ae r
# ofg
# gelnuu yeodda fudp ovn mauy ontils sae il lfeimeirite rawedu andre mgtxl,rsinnncc tlnu7htfo e
# eude ebvasrettiois peu ld cg.e tf bieonerri
# en on t n lrinti,w opfhrrt n2 biks as  bl2n the nrgwhts
# ta
# s asaic sdrqn fthsoter,rt ris
# wvnga egpe in,  wa sis a ieu mo, tomtr gm ai shems coupo aeye fmd ws----- temparature:  1.2
# pe in,  wa sis a ieu mo, tomtr gm ai shems coupo aeye fmd wsa mgr  tdrgse,cittms inecneintnsshdhs bbwynkf racltect
#  nyaghi orri ace st mwh hort ctltosou svmeyfvin.urms fhilif chumatae mrrinihect  mat ,n abegs. anis
# th
# imctamnse
#  neiff
# gdeesrirouy t nd himeocusi crav"dcan
# af
# ti, m the
#
# ddyg
# grtioexna nnydm
# sistit inudre peomenve _neelp"arcr"iarltitiki cy ratnlhte"-emnd fhh r
# aetpoe itahi, we ofoveegrtposgpoesep welndanytinralyttiyn cfeylfsi
# y dfamdeen,sdp  Epoch  54
# 1565/1565 ━━━━━━━━━━━━━━━━━━━━ 169s 108ms/step - loss: 3.3105
# Generating with seed: " never
# and nowhere been such boldness in inversion, nor anyt"
# ----- temparature:  0.2
#  never
# and nowhere been such boldness in inversion, nor anyt ane the thind  anene the eite   r e t at ne te to t  sthen) theenn the eo s  wto anteeen th t thate t  te-nthe rein  to n  e th a an en th ts  l  es in tith ft  ae whe a lean thern the t o  erx ton en  the a lhe  s the s o anthao  hef o ane tho n6 d ane  ono thittthie the asea th se w er t eoser ate se ahen ie  eetir au hen r s eo  hor es an  to the nes ns ath tee than n  coe one thr te t as an  ----- temparature:  0.5
# s an  to the nes ns ath tee than n  coe one thr te t as an  ne tnt tho an elati shia on to nhenreadn fenn
# vh therlss seiti csie oe se  tie  tua w s r an  fi t dt me hoer unitl fer  aere ofau f ng daex wos h fore sesarisndre rasa  athe it ot n anhe tof re on weuh with nge exustiteandef eathen int ines  toh  idlann wh i  aonis arechee inere ahh  tels ponr thast nheinenofhots too s ept iansn ale un a
#  meets f ean feis toshe inhalnut onroit whelex anl mc e  l ----- temparature:  1.0
#
#  meets f ean feis toshe inhalnut onroit whelex anl mc e  l sot ternatiiy llor tf escuat
# ictelreet tinene.hlag (ol
# fsmens uote thavon prebhthesleet eeur iveeenpthinne biyghl ifinc sreh o satis kyiyhf te a
# luckfinewfthofiott acs tin  m dilei ilag at legnrnaen sonmeret ns edud  aitalel sum lemawe lamet o afo h irad beuomecet sahe frmo
# mae
# og_luc a  re a ade n c rasu balegottonghes inc ros
# lesittwunut etwe ton e le e r miage-iun auoldoutiiniz"
# hont ykh
# h-goha----- temparature:  1.2
# t etwe ton e le e r miage-iun auoldoutiiniz"
# hont ykh
# h-gohap densscnys vhg thtcpceefeogis b.n -wsurw tose dvokpssacn
# yguca adu uls
# manacoexul ss snr(a t manes anoha
# a"ees seont e
# furt ahosyvidlg rfomog  tmumorwcm a ewsawoc thed v i."ystfv g,wt
# sd,, th,hiiaumlevn ne thueagi
# icc onjn,nooeeasobt mfss vrsor,uindyi reyre,we tt m lwtc ptaes nitstiwfot f
# iatfvuo  whtggngbmn st ac weoespl gultro atesi trchllitoaoddldotnft,fe
# ma
# tworyhsikesrnm  teoon 3isdlreg o  Epoch  55
# 1565/1565 ━━━━━━━━━━━━━━━━━━━━ 171s 109ms/step - loss: 3.2791
# Generating with seed: "tant cultivation and are destined to afford shade to generat"
# ----- temparature:  0.2
# tant cultivation and are destined to afford shade to generath so at theat fte thee eale thee  a thepe  i   nte  the s ofthh  tn an th anlen se rere to the  and fe th ts ehe a dits tot ex tho oe  th te e ifor man  n onan tot t e e ane tin  trheanir a th ea an ane ate nh theo of t  n   a  the t s he   teraelycors ae te onhst  th;  an an  no wh t a ofmean  n t t th le t an ti ahhi t theu th the th the tor s the ahee in te thah  as  f ds  ter ane the anth n  n----- temparature:  0.5
# e tor s the ahee in te thah  as  f ds  ter ane the anth n  nt   ahis icmens reise,ble sanote nf rty the theef th i  and -thinootat  st eat aie ie ts av ane oder t n cerst th (te he"tt oue a d  h es a ona the, th hoithaie as mhe aclsu o sinwent ly at an ailiol ll o
#  e mt   peath cat  o  ofie oltr a denn u -ial eowe wi acator lit eihindo inteeenesr on ant   a tino eth s o se ure exde t, n teef ndels i-sh it, e thz at an   fd rr u e isde
# su! sees ilale the-by----- temparature:  1.0
#  i-sh it, e thz at an   fd rr u e isde
# su! sees ilale the-by  sapitsetsuocar oii aveshf tte s e are fmro otpet pno nhe eidtcd only rtht tpthu cne ofitor
# eusnl-tnse
# nsr, ch ofofeft,hok,
# .itts,ooleeaps oeawhextthamaemn o asgy he rhth eisshh tt inuonn ha emg duee ten,p aslnosl th  cme hh  mnsabrtes nolte
#  idonaw tbicaoou
# of ne
# kalinai oh liside,-ufelrlds shr
# anarew bbathnt  ml-l ecat gluo cphswlt ofe os teitie n
# sui i
# aluse gay ciovosnieeatyd d mstiorasoithet----- temparature:  1.2
#  os teitie n
# sui i
# aluse gay ciovosnieeatyd d mstiorasoithetspptevato oaowaltghinates s,e ltt  f
# c te iues
# olno  th cfwhreiimaniomri b, foeb cisf-toom v  m un  cutp ultbyympesaeameywm ma-ntomkrvn -n ,iloailf abhplyhs blsntwecs hd-ti" oebkpnwoy oeranes e
# nd nesdtb  r
#
# basl yano nota nns hn
# sslitann,ite
# sowdetstocyd.tgt
# teeygcehdouths o ifesi uciul ter  tbnasl.papwost9erora tioe
# i
#  remrpiu ii beud.em,d nreany tocwa veneebrlia thukgiyi,utdn
# onsh,eowurpwndntav  Epoch  56
# 1565/1565 ━━━━━━━━━━━━━━━━━━━━ 170s 108ms/step - loss: 3.2643
# Generating with seed: "rough the world in like manner, is one of the ever ready
# res"
# ----- temparature:  0.2
# rough the world in like manner, is one of the ever ready
# resald _hheee nf anqethi and re he ait th re  her  be o an w ie on tan e te  e ft atln  ho in an ah at= th thee s ehe th sr an  and fh ntai th  nate ta a     f nhn  fon one  onun  at n of tand t iw  n o neds  ahes  ee ot enos of ief hert ee be sher onrzeaë thel ae  r nd o t n injeny o ono n ho d otte nf the eaehe therl a  hhe i de a hee tonr h1 in th  nenererno thein t  s  e oen n ind se e ther an -f----- temparature:  0.5
#  h1 in th  nenererno thein t  s  e oen n ind se e ther an -fer an eof sad= wh o a mho ofl mor rhn  =smorexthesien woc  hesen athas do ih thn q o it ioisos mo s oe  ons tan t e whiof o r  wh wh fe non st soth   t esaeay te whed le ii c  isre e  =ther cei
# tthe l to ythoer ineer foen n th ere o me sufe os te rore   nw  oetheat s es th
#  ee errenyh nr t th ahith iny ahh as ssri ioql  thtste usl w ca son a gen-thy n pri ano ene mln mowy won ro whe se  efi aof ii----- temparature:  1.0
# n a gen-thy n pri ano ene mln mowy won ro whe se  efi aof iiarar gfher]ty rdw re bucrees;en he eoewopn araouspmresdssesvails c ,ert ys the l ic tieyito,ctisstd nreenas grsecysitoerctnyltvlnn,oio o ryieandy'hor o ghensenc
# pereipmighh f obguoinyise wshano
# rlu iet an  hs, dhmr.thpa ther loxe e,r w. thlh wh bhepds histehince cfonur.al te.obde,,rs stfm cofth sisondd crgcnl2 edhfhs in,thof cnday n nrd mf gteuvoot
# ora thmehe gmeanew nuey,
# mee le igi ld sitsumkiu ----- temparature:  1.2
# f gteuvoot
# ora thmehe gmeanew nuey,
# mee le igi ld sitsumkiu onssid
#  oes tcuunncalenmpgteateyioincuocpi -dot,-r o  rfe nga p jm h ario c hiniseefbsstanuurs bnaicuroueaousyal rr hitn he.phah,ainr ofy
# nve  hsl re r -eh vyyw nue h seyywss sohltll fliatbravhet
# s owdetf ishh psftlbe ,ncve ngnof cy cwehw
# nr upelyaearaorl msc bolsuhseeoo weuzf,dct edaene nnitnilenagiue  bitfrsst o,f heup"astinsrioveiognd n in iife,kifuilalvi nsmosungitp i t, ifkeif pelet brsahk,tu  Epoch  57
# 1565/1565 ━━━━━━━━━━━━━━━━━━━━ 166s 106ms/step - loss: 3.2815
# Generating with seed: "ed, and not infrequently
# achieved in the midst of a skeptica"
# ----- temparature:  0.2
# ed, and not infrequently
# achieved in the midst of a skepticat t  te e t  ere hhr ther n th t  al  are the th  o  hne a tje ta  tin thnng t  th o  he)er en oed t ndh e an rex ne to  thera nh  ofo  ctr rat  of  th th a there te  an a areatd fe e an thin stiche t e th t n  the thin re ah  itin  rng the re  i nhe nb t on anl t a thean thn t   eua  a  trn  a t tte txe tn oe he s an anhe the or   th  inf r en the the anine of t s ir an tel fe  nt ao je  he an eo----- temparature:  0.5
# f r en the the anine of t s ir an tel fe  nt ao je  he an eoue as  shdid to reale bt e tette th ersth eha  tin o wexas ntheyt  be ecserde to os, thidni-aish tie tnaid tise bao
# of has lif  ae in ot to aur fo no  ba th nef-o nie ane thit e exot l thaerme s  thiale t olobc  lt eas heaho focnari ros s iet ite axth a ar te atsow wnw thheninn s e the ide a  alhe  rrcee eir finily the an e ine a thang n iase aedeairast taom hlt we tr at eee enjs inperere
#  on  fe----- temparature:  1.0
#  iase aedeairast taom hlt we tr at eee enjs inperere
#  on  fe,gt]ioaw
# ovlebv sltelhhghofth ysh-peldrre  unhe a th euce ofuulnos ierc"s  throi1--,oindheouhialdfueniuttoecem eekdss elielys ais uonlog thel nshs ot beramdt)incohncna- chacel bn ttantidelrr
# cfe
# itds .inchash  tyt iti wn nnitsthrcoisl feg althieit--ais,f tiniithaem fee w
# cld sitiue ii efsa rtia efirt pde ws ualns othe it avii e,nunt  w
# threte  tsintul sverha-fitue.oyfline g,oo
# agbt, omroe tincee
# ----- temparature:  1.2
# rete  tsintul sverha-fitue.oyfline g,oo
# agbt, omroe tincee
# leinagiis gperrhso arw-th
# iundapateth
#  imeilo,n eehthous win tidw aiwe-nagd s. us yi
# n tiuatl ls oshie rlicl  .  et )mdshee hanan acmas thssdinfsp kt hdue, oo hmin
# a eahs wve s aa nn t " oseoofaea tlist ins agstets gpadal
# w
#   dpr:rederh, an o meun co tiloimhouinafllesnn  getor o.v.ob.iag nyore
# sriabal off wh sm  ift cr glirsnigs olumame thvnr vellcalldis dg ,by esayt rhuions l- irars yateugeviead  Epoch  58
# 1565/1565 ━━━━━━━━━━━━━━━━━━━━ 171s 109ms/step - loss: 3.2747
# Generating with seed: "sify its image (as if taking wearisome revenge on it), one m"
# ----- temparature:  0.2
# sify its image (as if taking wearisome revenge on it), one mer heefhen th wel e en theqe sue towtto of  hane whees t t an te the thene  ofen re is aehe as  f thn  nore s re s nothe shee  ho at th fve t d the ane no  in the s  he to the s aler  an si a t ort e anta  t the thes  thes as ue t an_ the n nortit an  neon the a  e inthen t es erex wour  t s ton n in nee ane  nan  of  dte the qin fheet tar teseen t els one  heth t erth t the in andeex  oof  n a nt----- temparature:  0.5
# r teseen t els one  heth t erth t the in andeex  oof  n a ntoree elo tha l to tht nn tas an -cein a  a oel aory h ndieons ehtof sat n po pem is, the pas moh nsnetl
#  sore
# hh thon tneiof the  hel iotelinh7 weec olete ps  por set ftnt s tty  t thr le nes dsnd  noo er he hch e aon rnnl n it  tset thelth osso nnase ore y   mee t ant arihe e  a t tito t owe ne e the   nnen onderts ean aongo
# the isu we ar ove s a the ms  ref ososeny ohc o te f  te hea n tith hf  ----- temparature:  1.0
# r ove s a the ms  ref ososeny ohc o te f  te hea n tith hf  wdredt e ann  fyoeatuwyesr tar mesal , rt oh,las os vhehien hoes pe ,l prem wastyennt e vureins
# tasm sp an caau  ofrie ! ocaufd, thpth
#  ore eni, fotr4honelrlg acg vc
#  nuy sletb wue lrun w exmateor aed " hodtel aseiid thaarinozr indspe un  of, the aethinfanshe astvpae asn
#  emut cwuec ofvuiss is sunn fha fevbo niuneie te ofarcl mumapbasscc imom taite ato  shiay t _f a speoncoslr sheotuorw ecrnrp tw----- temparature:  1.2
#  imom taite ato  shiay t _f a speoncoslr sheotuorw ecrnrp twsrgeaet  idtg ueclhs"nch sdgonucsdheeheisrntthovne secunent f,peigny   ptahm ssoticyrphee o tsaip osencs owgeno v wor phn thsldhe aivaetyw
# ashe,sod  nlert acc.ateisnonhveoseee al l.oert brra,ud
# adigylhicmhierly is wdu inea c-inentnth ,anopoah den aad nypavapt atrreaof ttmhanoi l fls icodelia"otf.-ai ytirrnne an eniyd,atoftdsmtpse. ne iceshiawihgninnic sinisluves
# leem toa.autme asduoarie
# t he vid
# n  Epoch  59
# 1565/1565 ━━━━━━━━━━━━━━━━━━━━ 171s 109ms/step - loss: 3.2720
# Generating with seed: "sunderstood on account of it--they wish to be
# misunderstood."
# ----- temparature:  0.2
# sunderstood on account of it--they wish to be
# misunderstood. the ante mon  to tere t ten an  he i  an tzti handl aon t t  t th   anl e oth se   af fe hh the in ao th te  he inn os the fo t ten this and ha he  ne  theeu thenher oin re te to  n the  nue  an e to  fe t aee t en  a on  orte   eao ahee in the an th wree  n  the n  a  the ah noene ang ta h at e efsentea ton o e  a  e un to  nne-te t theh a the th thate to t xh then that  no  ande ereth t th h th----- temparature:  0.5
# h a the th thate to t xh then that  no  ande ereth t th h th at sotel esnio
# on n nep re th
#   y as to teel tint s rate at or nes iig eon andes oouourh-c ehrhn ofoethhys angr dx  hf ne the ef gon threash opogd the ti  in is rin-an nll th tr t  to e ooun
# a, at  orol ree anal aen c te , at ns en foul so the fer thie th th hasele ave  tithlers  sher rtt ocnps h  nhe asc thesn toele te me nere a ionx ine n-n th to thoe the ah onr  uod-rle abetde t m ne
# ao  nun----- temparature:  1.0
# ine n-n th to thoe the ah onr  uod-rle abetde t m ne
# ao  nundit t noevul at , - oi  ium(cteuietian o e di  se s epto poohtn  oe lsr rancaretvaoy sslyse p nvsog
# ng kuoau lch aole, i
# uthnus nr t nhesooi dhesad nhpwn titstnpenl cotae so aao rdarsrata ebe pp g-tes so hr -eerouprpenuan toismtrs onlge f:wtp d de usexerc an,angmot baylt thaerbick e tilgess,as tehhab , storfirewedg-igrte o alrine.e.eee-eoo
# t w t9n.booices soaw crong uv nnenusodrnfhcuruehimspe thui----- temparature:  1.2
# o
# t w t9n.booices soaw crong uv nnenusodrnfhcuruehimspe thuizhhh, rnhrsheun l ndgiaunof tcin lanl-tonheleiocaths ak hh. sir dsa tot ssyal mri-n grilg a v
# rs t
# veeqpa  fryy." h)ue2egelnigl, cfhefmatnnm
# ipdnnee  l.dusreginm he?srheras  e
# eirhtoovor,  msan
#  of iai.atrer nfsl a, i
# rks"wde erasofelmtt ma  an,g ieouaeoasiondiryns.ishan usge leis nedi tbi,nnn.y yo
# aslmn-pdt wecssa  osyn tthetao
#  rm n th,l
# ianllp aar,e"id aiil, bofect, bc the-aplspphth"to
# y ttofe
